# %%
import pandas as pd
import numpy as np

# %%
producteurs = pd.read_csv('producteurs.csv')
ventes = pd.read_csv("ventes.csv")
recoltes = pd.read_csv("recoltes.csv")

# %% [markdown]
# # EXPLORATION

# %%
print(f"La taille du fichier producteurs est : {producteurs.shape}")
print(f"La taille du fichier ventes est : {ventes.shape}")
print(f"La taille du fichier recoltes est : {recoltes.shape}")
# Out:
# La taille du fichier producteurs est : (31, 8)
# La taille du fichier ventes est : (111, 6)
# La taille du fichier recoltes est : (91, 5)

# %% [markdown]
# ### Informations sur chaque fichier

# %%
producteurs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   producteur_id         31 non-null     int64
#  1   nom                   31 non-null     object
#  2   prenom                31 non-null     object
#  3   sexe                  31 non-null     object
#  4   region                31 non-null     object
#  5   prefecture            31 non-null     object
#  6   annee_debut_activite  31 non-null     int64
#  7   superficie_ha         29 non-null     float64
# dtypes: float64(1), int64(2), object(5)
# memory usage: 2.1+ KB

# %%
ventes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 111 entries, 0 to 110
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   vente_id            111 non-null    int64
#  1   recolte_id          111 non-null    int64
#  2   marche              111 non-null    object
#  3   date_vente          111 non-null    object
#  4   prix_unitaire_fcfa  111 non-null    int64
#  5   quantite_vendue_kg  111 non-null    float64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 5.3+ KB

# %%
recoltes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91 entries, 0 to 90
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   recolte_id     91 non-null     int64
#  1   producteur_id  91 non-null     int64
#  2   culture        91 non-null     object
#  3   date_recolte   91 non-null     object
#  4   quantite_kg    79 non-null     float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 3.7+ KB

# %% [markdown]
# ### Recherche des valeurs manquantes

# %%
print(f"Sur producteurs : {producteurs.isna().sum()}")
print()
print(f"Sur ventes : {ventes.isna().sum()}")
print()
print(f"Sur recoltes : {recoltes.isna().sum()}")
# Out:
# Sur producteurs : producteur_id           0
# nom                     0
# prenom                  0
# sexe                    0
# region                  0
# prefecture              0
# annee_debut_activite    0
# superficie_ha           2
# dtype: int64
#
# Sur ventes : vente_id              0
# recolte_id            0
# marche                0
# date_vente            0
# prix_unitaire_fcfa    0
# quantite_vendue_kg    0
# dtype: int64
#
# Sur recoltes : recolte_id        0
# producteur_id     0
# culture           0
# date_recolte      0
# quantite_kg      12
# dtype: int64

# %% [markdown]
# ### Combien de producteur_id apparaissent dans recoltes mais pas dans producteurs ? Combien de recolte_id apparaissent dans ventes mais pas dans recoltes

# %%
prod_invalides = recoltes[~recoltes["producteur_id"].isin(producteurs["producteur_id"])]
print("producteur_id invalides dans recoltes :", prod_invalides["producteur_id"].unique())
# Out:
# producteur_id invalides dans recoltes : [301 305 310]

# %%
 recolte_invalides = ventes[~ventes["recolte_id"].isin(recoltes["recolte_id"])]
print("recolte_id invalides dans ventes :", recolte_invalides["recolte_id"].unique())
# Out:
# recolte_id invalides dans ventes : [9002 9003 9001]

# %% [markdown]
# # NETTOYAGE

# %% [markdown]
# ### Suppression des doublons

# %%
producteurs = producteurs.drop_duplicates()
ventes = ventes.drop_duplicates()
recoltes = recoltes.drop_duplicates()

# %%
print(f"Dupliqué sur producteurs : {producteurs.duplicated().sum()}")
print(f"Dupliqué sur ventes : {ventes.duplicated().sum()}")
print(f"Dupliqué sur recoltes : {recoltes.duplicated().sum()}")
# Out:
# Dupliqué sur producteurs : 0
# Dupliqué sur ventes : 0
# Dupliqué sur recoltes : 0

# %% [markdown]
# ### Uniformiser la colonne 'region' de producteurs

# %%
producteurs['region'] = producteurs['region'].str.lower().str.title()

# %% [markdown]
# ### Utilisation de fillna

# %%
for df, nom in [(producteurs, "producteurs"), (recoltes, "recoltes"), (ventes, "ventes")]:
    print(nom, df.columns)
# Out:
# producteurs Index(['producteur_id', 'nom', 'prenom', 'sexe', 'region', 'prefecture',
#        'annee_debut_activite', 'superficie_ha'],
#       dtype='object')
# recoltes Index(['recolte_id', 'producteur_id', 'culture', 'date_recolte',
#        'quantite_kg'],
#       dtype='object')
# ventes Index(['vente_id', 'recolte_id', 'marche', 'date_vente', 'prix_unitaire_fcfa',
#        'quantite_vendue_kg'],
#       dtype='object')

# %% [markdown]
# #### Sur superficie_ha

# %%
moy_sup_ha = producteurs['superficie_ha'].mean()
producteurs['superficie_ha'] = producteurs['superficie_ha'].fillna(moy_sup_ha)

# %% [markdown]
# #### Sur quantite_kg

# %%
moy_quant_kg = recoltes['quantite_kg'].mean()
recoltes['quantite_kg']  = recoltes['quantite_kg'].fillna(moy_quant_kg)

# %% [markdown]
# # JOINTURE EN CASCADE

# %% [markdown]
# ### Jointure interne entre recoltes et producteurs sur 'producteur_id'

# %% [markdown]
# - La taille initiale du fichier producteurs est : (31, 8)
# - La taille initiale du fichier ventes est : (111, 6)

# %%
rp = pd.merge(recoltes, producteurs, on="producteur_id", how="inner")
rp.shape
# Out:
# (81, 12)

# %% [markdown]
# ### Jointure interne entre ventes et 'rp' sur 'recolte_id'

# %% [markdown]
# - La taille initiale du fichier recoltes est : (91, 5)
# - La taille du fichier rp est : (81, 12)

# %%
full = pd.merge(ventes, rp, on="recolte_id", how="inner")
full.shape
# Out:
# (88, 17)

# %% [markdown]
# # COLONNES DERIVEES

# %%
full.head()
# Out:
#    vente_id  recolte_id             marche  date_vente  prix_unitaire_fcfa  \
# 0      4002        3008    Marché de Notsé  2024-11-14                 150
# 1      4003        3057  Marché d'Adawlato  2023-10-11                 150
# 2      4004        3080  Marché de Kpalimé  2023-11-11                 150
# 3      4006        3037  Marché de Dapaong  2024-01-06                 250
# 4      4007        3084   Marché de Sokodé  2022-07-18                 400
#
#    quantite_vendue_kg  producteur_id culture date_recolte  quantite_kg  \
# 0               596.7              9   Coton   2024-02-16        660.3
# 1               435.7             11    Maïs   2022-04-16       1045.2
# 2               934.3             29  Igname   2022-02-13       1713.8
# 3                51.9              8     Riz   2024-06-13       2038.6
# 4               771.1             21    Maïs   2022-07-03       1817.5
#
#         nom prenom sexe    region prefecture  annee_debut_activite  \
# 0    Sassou   Abla    F  Plateaux    Kpalimé                  2006
# 1     Bissa    Ama    F      Kara     Bassar                  2014
# 2     Nyaku   Sena    M      Kara       Kara                  2013
# 3    Adjovi   Abla    F   Savanes    Dapaong                  2009
# 4  Tchamdja  Komla    M      Kara       Kara                  2017
#
#    superficie_ha
# 0       3.842857
# 1       4.400000
# 2       1.700000
# 3       3.900000
# 4       3.842857

# %% [markdown]
# ### Nouvelle colonne

# %%
full['revenu_fcfa'] = full['prix_unitaire_fcfa'] * full['quantite_vendue_kg']

# %%
full[['revenu_fcfa', 'nom']]
# Out:
#     revenu_fcfa       nom
# 0       89505.0    Sassou
# 1       65355.0     Bissa
# 2      140145.0     Nyaku
# 3       12975.0    Adjovi
# 4      308440.0  Tchamdja
# ..          ...       ...
# 83      84850.0     Bissa
# 84     115020.0      Foli
# 85     256760.0      Foli
# 86     289225.0      Pali
# 87     329550.0    Sassou
#
# [88 rows x 2 columns]

# %% [markdown]
# ### Conversion de la date

# %%
full["date_vente"] = pd.to_datetime(full["date_vente"], dayfirst=False, errors="coerce")

# %%
full['mois_vente'] = full['date_vente'].dt.month
full['annee_vente'] = full['date_vente'].dt.year

# %% [markdown]
# ### Nouvelle colonne

# %%
def classer_revenu(row):
    if row["revenu_fcfa"] > 300000:
        return "Élevé"
    elif row["revenu_fcfa"] > 100000:
        return "Moyen"
    else:
        return "Faible"
 
full["niveau_revenu"] = full.apply(classer_revenu, axis=1)
print(full["niveau_revenu"].value_counts())
# Out:
# niveau_revenu
# Moyen     42
# Élevé     25
# Faible    21
# Name: count, dtype: int64

# %% [markdown]
# # AGREGATIONS

# %%
revenu_par_region = (full.groupby("region")["revenu_fcfa"].agg(["sum", "mean", "count"]).sort_values("sum", ascending = False))
revenu_par_region
# Out:
#                 sum           mean  count
# region
# Kara      6350340.0  218977.241379     29
# Savanes   5455575.0  247980.681818     22
# Plateaux  4626340.0  231317.000000     20
# Centrale  2652005.0  241091.363636     11
# Maritime  1157555.0  192925.833333      6

# %%
culture_par_region = full.pivot_table(values="revenu_fcfa", index="region", columns="culture", aggfunc="sum", fill_value=0)
culture_par_region
# Out:
# culture      Cacao       Café      Coton     Igname     Manioc       Maïs  \
# region
# Centrale  330300.0        0.0    29550.0   761995.0        0.0  1240935.0
# Kara      572250.0  1969975.0   453565.0  1657965.0   121650.0   564415.0
# Maritime  467040.0   553215.0   137300.0        0.0        0.0        0.0
# Plateaux  960280.0   256760.0  1194100.0    68370.0  1143780.0  1003050.0
# Savanes   928335.0   916400.0  1683305.0   451950.0   627190.0        0.0
#
# culture        Riz    Sorgho
# region
# Centrale       0.0  289225.0
# Kara      545340.0  465180.0
# Maritime       0.0       0.0
# Plateaux       0.0       0.0
# Savanes   369980.0  478415.0

# %%
culture_top = culture_par_region.sum(axis=0).sort_values(ascending=False).index[0]
print("Culture générant le plus de revenu :", culture_top)
# Out:
# Culture générant le plus de revenu : Café

# %% [markdown]
# # NUMPY

# %%
print(f"La moyenne de revenu_fcfa est {np.mean(full['revenu_fcfa'])}")
print(f"La mediane de revenu_fcfa est {np.median(full['revenu_fcfa'])}")
print(f"L'ecart type de revenu_fcfa est {np.std(full['revenu_fcfa'])}")
# Out:
# La moyenne de revenu_fcfa est 230020.625
# La mediane de revenu_fcfa est 207430.0
# L'ecart type de revenu_fcfa est 160302.08977862223

# %%
atypiques = full[full['revenu_fcfa'] > np.mean(full['revenu_fcfa']) + 2 * np.std(full['revenu_fcfa'])]
atypiques.head()
# Out:
#     vente_id  recolte_id             marche date_vente  prix_unitaire_fcfa  \
# 56      4073        3087  Marché d'Adawlato 2023-10-15                 500
# 71      4090        3045  Marché de Kpalimé 2023-06-15                 500
# 80      4100        3056    Marché de Notsé 2024-08-06                 400
#
#     quantite_vendue_kg  producteur_id culture date_recolte  quantite_kg  ...  \
# 56              1175.3              1    Café   2023-10-26  1476.300000  ...
# 71              1446.8             26   Cacao   2024-11-13  1439.100000  ...
# 80              1435.6             23  Manioc   2024-07-24  1652.960256  ...
#
#     prenom sexe    region prefecture annee_debut_activite  superficie_ha  \
# 56   Adjoa    F      Kara       Kara                 2019            2.5
# 71  Akpene    F  Plateaux   Atakpamé                 2018            4.2
# 80  Akosua    F   Savanes    Dapaong                 2010            1.5
#
#     revenu_fcfa  mois_vente  annee_vente  niveau_revenu
# 56     587650.0          10         2023          Élevé
# 71     723400.0           6         2023          Élevé
# 80     574240.0           8         2024          Élevé
#
# [3 rows x 21 columns]

# %% [markdown]
# **La région Kara génère le revenu total le plus élevé et concentre le plus grand nombre de ventes.**
#
# **La culture la plus rentable au global est le Café.**
#
# **On recommanderait de renforcer l'appui (semences, formation) sur cette combinaison région/culture pour maximiser l'impact.**

# %% [markdown]
# # BONUS : GRAPHIQUE

# %%
import matplotlib.pyplot as plt

# %%
viz = full.groupby('region')['revenu_fcfa'].sum().sort_values(ascending=False)

plt.figure(figsize=(12,5))

plt.bar(viz.index, viz.values)
plt.title("La region avec le revenu le plus eleve")
plt.show()

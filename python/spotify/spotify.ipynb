# %% [markdown]
# ## About Dataset
#
#
# **Rows**: Each row represents a unique Spotify user.
#
# **Columns**:
#
#         user_id → Unique identifier for each user
#
#         gender → User gender (Male/Female/Other)
#
#         age → User age
#
#         country → User location
#
#         subscription_type → Type of Spotify subscription (Free, Premium, Family, Student)
#
#         listening_time → Minutes spent listening per day
#
#         songs_played_per_day → Number of songs played daily
#
#         skip_rate → Percentage of songs skipped
#
#         device_type → Device used (Mobile, Desktop, Web)
#
#         ads_listened_per_week → Number of ads heard per week
#
#         offline_listening → Offline mode usage

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("spotify_churn_dataset.csv")
print("Cinq premieres lignes : ")
df.head()
# Out:
# Cinq premieres lignes :
#    user_id  gender  age country subscription_type  listening_time  \
# 0        1  Female   54      CA              Free              26
# 1        2   Other   33      DE            Family             141
# 2        3    Male   38      AU           Premium             199
# 3        4  Female   22      CA           Student              36
# 4        5   Other   29      US            Family             250
#
#    songs_played_per_day  skip_rate device_type  ads_listened_per_week  \
# 0                    23       0.20     Desktop                     31
# 1                    62       0.34         Web                      0
# 2                    38       0.04      Mobile                      0
# 3                     2       0.31      Mobile                      0
# 4                    57       0.36      Mobile                      0
#
#    offline_listening  is_churned
# 0                  0           1
# 1                  1           0
# ...

# %%
print(f"Taille : {df.shape[0]} lignes | {df.shape[1]} colonnes")
# Out:
# Taille : 8000 lignes | 12 colonnes

# %%
df.drop(columns = ['is_churned', 'user_id'], axis=1 , inplace=True)

# %%
print(f"Taille : {df.shape[0]} lignes | {df.shape[1]} colonnes")
# Out:
# Taille : 8000 lignes | 10 colonnes

# %%
df.head()
# Out:
#    gender  age country subscription_type  listening_time  \
# 0  Female   54      CA              Free              26
# 1   Other   33      DE            Family             141
# 2    Male   38      AU           Premium             199
# 3  Female   22      CA           Student              36
# 4   Other   29      US            Family             250
#
#    songs_played_per_day  skip_rate device_type  ads_listened_per_week  \
# 0                    23       0.20     Desktop                     31
# 1                    62       0.34         Web                      0
# 2                    38       0.04      Mobile                      0
# 3                     2       0.31      Mobile                      0
# 4                    57       0.36      Mobile                      0
#
#    offline_listening
# 0                  0
# 1                  1
# 2                  1
# 3                  1
# 4                  1

# %%
print("Elements vides par colonnes : ")
print("-----------------------------")
df.isna().sum()
# Out:
# Elements vides par colonnes :
# -----------------------------
# gender                   0
# age                      0
# country                  0
# subscription_type        0
# listening_time           0
# songs_played_per_day     0
# skip_rate                0
# device_type              0
# ads_listened_per_week    0
# offline_listening        0
# dtype: int64

# %% [markdown]
# **Pas de valeurs manquantes dans ce dataset**

# %% [markdown]
# ### PROPORTIONS PAR VARIABLES CATEGORIELLLES

# %%
print("Proportion de repartition sur le genre : ")
df['gender'].value_counts(normalize=True)
# Out:
# Proportion de repartition sur le genre :
# gender
# Male      0.336375
# Female    0.332375
# Other     0.331250
# Name: proportion, dtype: float64

# %% [markdown]
# **La répartition du dataset est parfait le genre.**

# %%
print("Proportion de repartition sur le type de subscription : ")
df['subscription_type'].value_counts(normalize=True)
# Out:
# Proportion de repartition sur le type de subscription :
# subscription_type
# Premium    0.264375
# Free       0.252250
# Student    0.244875
# Family     0.238500
# Name: proportion, dtype: float64

# %% [markdown]
# **La répartition du dataset est parfait le type de souscription.**

# %%
print("Proportion de repartition sur le type d'appareil : ")
df['device_type'].value_counts(normalize=True)
# Out:
# Proportion de repartition sur le type d'appareil :
# device_type
# Desktop    0.347250
# Web        0.327875
# Mobile     0.324875
# Name: proportion, dtype: float64

# %% [markdown]
# **La répartition du dataset est parfait le type de souscription.**

# %%
print("Proportion de repartition sur les pays : ")
df['country'].value_counts(normalize=True)
# Out:
# Proportion de repartition sur les pays :
# country
# AU    0.129250
# US    0.129000
# DE    0.126875
# IN    0.126375
# PK    0.124875
# FR    0.123625
# UK    0.120750
# CA    0.119250
# Name: proportion, dtype: float64

# %% [markdown]
# **La répartition du dataset est parfait les pays.**
